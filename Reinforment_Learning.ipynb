# %%
# Dependencies
import sys
import pylab as plb
import numpy as np
import mountaincar
import DummyAgent as DA

# %% [markdown]
# ### Let's RUN IT!

# %%
d = DA.DummyAgent()
d.visualize_trial()
plb.show()
# Out:
# t = 0.0
# t = 1.0
# t = 2.0
# t = 3.0
# t = 4.0
# t = 5.0
# t = 6.0
# t = 7.0
# t = 8.0
# t = 9.0
# t = 10.0
# t = 11.0
# t = 12.0
# t = 13.0
# t = 14.0
# t = 15.0
# t = 16.0
# t = 17.0
# t = 18.0
# t = 19.0
# t = 20.0
# t = 21.0
# t = 22.0
# t = 23.0
# t = 24.0
# t = 25.0
# t = 26.0
# t = 27.0
# t = 28.0
# t = 29.0
# t = 30.0
# t = 31.0
# t = 32.0
# t = 33.0
# t = 34.0
# t = 35.0
# t = 36.0
# t = 37.0
# t = 38.0
# t = 39.0
# t = 40.0
# t = 41.0
# t = 42.0
# t = 43.0
# t = 44.0
# t = 45.0
# t = 46.0
# t = 47.0
# t = 48.0
# t = 49.0
# t = 50.0
# t = 51.0
# t = 52.0
# t = 53.0
# t = 54.0
# t = 55.0
# t = 56.0
# t = 57.0
# t = 58.0
# t = 59.0
# t = 60.0
# t = 61.0
# t = 62.0
# t = 63.0
# t = 64.0
# t = 65.0
# t = 66.0
# t = 67.0
# t = 68.0
# t = 69.0
# t = 70.0
# t = 71.0
# t = 72.0
# t = 73.0
# t = 74.0
# t = 75.0
# t = 76.0
# t = 77.0
# t = 78.0
# t = 79.0
# t = 80.0
# t = 81.0
# t = 82.0
# t = 83.0
# t = 84.0
# t = 85.0
# t = 86.0
# t = 87.0
# t = 88.0
# t = 89.0
# t = 90.0
# ...
