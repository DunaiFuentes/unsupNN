# %%
# Dependencies
import sys
import pylab as plb
import numpy as np
import mountaincar
import DummyAgent as DA
import NeuralAgent_v1 as NA1
import NeuralAgent_v3 as NA3
# %matplotlib inline

# %%
n_neurons = 20 # Actually a n_neuros x n_neurons grid
tau = 0.0001#Exploration temperature parameter
eta = 0.002 #Learning rate
gamma = 0.95 #Reward factor
lambda_eligibility = 0.95 #elegibility decay
a = NA3.NeuralAgent(n_neurons,tau,eta,gamma,lambda_eligibility)
# Out:
# [-150.         -140.52631579 -131.05263158 -121.57894737 -112.10526316
#  -102.63157895  -93.15789474  -83.68421053  -74.21052632  -64.73684211
#   -55.26315789  -45.78947368  -36.31578947  -26.84210526  -17.36842105
#    -7.89473684    1.57894737   11.05263158   20.52631579   30.        ]
# 9.47368421053
# [-15.         -13.42105263 -11.84210526 -10.26315789  -8.68421053
#   -7.10526316  -5.52631579  -3.94736842  -2.36842105  -0.78947368
#    0.78947368   2.36842105   3.94736842   5.52631579   7.10526316
#    8.68421053  10.26315789  11.84210526  13.42105263  15.        ]
# 1.57894736842

# %%
N_trials = 100
N_runs=1
max_steps = 4000 #Save stop if not working well
latencies,vec_field = a.run(N_trials,N_runs,max_steps)
print(latencies)
# Out:
# Starting trial at position (-68.31871315313009,2.0336740809606892)
# /Users/vidit/Semester3/Unsupervised Learning NN/unsupNN/Project2/NeuralAgent_v3.py:182: VisibleDeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   self.mountain_car.apply_force(self.force[self.action])
# /Users/vidit/Semester3/Unsupervised Learning NN/unsupNN/Project2/NeuralAgent_v3.py:201: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if self.action_old != None:
# 3198
# [ 0.02538429  0.0301527   0.00878261]
# Starting trial at position (-120.95744757102335,-4.180860083860396)
# 400
# [ 0.04761773  0.06370483  0.01656859]
# Starting trial at position (-62.04114514915199,-4.473275463400334)
# 232
# [ 0.06302457  0.10560665  0.02324241]
# Starting trial at position (-70.21755328159746,-0.9233793066430094)
# 372
# [ 0.07734769  0.14892847  0.02933377]
# Starting trial at position (-93.24480655744829,-1.6993663339552176)
# 1796
# [ 0.09315217  0.19209793  0.03407017]
# Starting trial at position (-83.86912458436225,-2.2728506507192217)
# 1630
# [ 0.10367899  0.24268679  0.0368655 ]
# Starting trial at position (-75.31143224927357,1.1695251213615734)
# 2166
# [ 0.11978458  0.28602052  0.04161789]
# Starting trial at position (-61.62577871612109,2.8585343544194846)
# 138
# [ 0.12304035  0.34513677  0.04255878]
# Starting trial at position (-67.93910878074223,4.915930387191231)
# 131
# [ 0.14071089  0.38515774  0.04787072]
# Starting trial at position (-71.11231304055809,0.925289984236187)
# 2164
# [ 0.1548885   0.43221266  0.0504716 ]
# Starting trial at position (-83.37696742487225,-0.7372516074046986)
# 702
# [ 0.16803894  0.48067554  0.05298633]
# Starting trial at position (-103.11884123411319,1.0920103902723524)
# 1176
# [ 0.17932131  0.53115254  0.05522408]
# Starting trial at position (-99.24303062846869,1.731081916196752)
# 762
# [ 0.19749113  0.57139198  0.06076633]
# Starting trial at position (-57.582310772715715,3.1122361802704006)
# 99
# [ 0.20845594  0.62201527  0.06290501]
# Starting trial at position (-84.36702711225576,1.6992845239371803)
# 435
# [ 0.22824626  0.65849152  0.06887366]
# Starting trial at position (-129.85243727050957,-3.4938633784500595)
# 115
# [ 0.24221909  0.7045084   0.07170258]
# Starting trial at position (-113.30260378038463,-0.4439632899527668)
# 534
# [ 0.25622436  0.75050009  0.07454696]
# Starting trial at position (-51.102747459242025,-4.479710536987708)
# 100
# [ 0.27624418  0.78641576  0.08074706]
# Starting trial at position (-110.72142207817274,-0.23401518622564232)
# 621
# [ 0.29472232  0.82608085  0.08650291]
# Starting trial at position (-65.81676209056607,0.0726040064253688)
# 145
# [ 0.3059249   0.87421002  0.09091286]
# Starting trial at position (-77.36820604923243,-4.007716424631464)
# 268
# [ 0.32156151  0.91795806  0.09409728]
# Starting trial at position (-83.60977564880928,2.3721178702215866)
# 428
# [ 0.32718674  0.97293138  0.09635084]
# Starting trial at position (-126.50316645103325,-3.5094327043773443)
# 113
# [ 0.33923165  1.02217511  0.09883831]
# Starting trial at position (-70.77299459940097,-3.5961775593057888)
# 142
# [ 0.35491085  1.0651942   0.10373366]
# Starting trial at position (-101.93637480743902,-2.036408284098661)
# 467
# [ 0.37481528  1.09845772  0.10990372]
# Starting trial at position (-79.01944692666282,-4.497708194677427)
# 188
# [ 0.38721961  1.14406829  0.11484923]
# Starting trial at position (-112.59538623784721,1.2116922699897215)
# 200
# [ 0.39781559  1.1935395   0.11902663]
# Starting trial at position (-90.07799511759885,3.920159797178357)
# 175
# [ 0.41126619  1.24034691  0.12198077]
# Starting trial at position (-67.1741963746456,-4.805723398291332)
# 122
# [ 0.42125679  1.29063556  0.12410406]
# Starting trial at position (-80.77999083541786,-1.412223578855254)
# 215
# [ 0.43587393  1.3331752   0.12724911]
# Starting trial at position (-57.2237944578262,4.227977869831603)
# 102
# [ 0.45236202  1.37218992  0.133719  ]
# Starting trial at position (-115.8758776518548,-3.036200758983627)
# 264
# [ 0.46715356  1.41668908  0.13690923]
# Starting trial at position (-108.9018949872486,0.2989165293889986)
# 253
# [ 0.47496052  1.4685965   0.13865791]
# Starting trial at position (-89.18912220822932,-2.376274642503132)
# 307
# [ 0.48962141  1.51456773  0.14161398]
# Starting trial at position (-84.4746091782373,3.858068529816899)
# 441
# [ 0.50618353  1.55725499  0.14518818]
# Starting trial at position (-81.3339446218533,-0.6777955782912057)
# 293
# [ 0.51826051  1.60273476  0.14786271]
# Starting trial at position (-126.45153748093861,2.2935506552773335)
# 141
# [ 0.53283023  1.64356857  0.15106384]
# Starting trial at position (-97.2927610279029,4.103389931939908)
# 265
# [ 0.54492499  1.68982569  0.15611218]
# Starting trial at position (-109.00351456986331,-3.0281704231545827)
# 259
# [ 0.55850275  1.72685969  0.16190605]
# Starting trial at position (-84.66214055136503,-1.4703109527783234)
# 294
# [ 0.57307667  1.75826483  0.16855107]
# Starting trial at position (-122.877832240172,-0.9156215046876417)
# 129
# [ 0.58578856  1.80403198  0.17455695]
# Starting trial at position (-127.61198715967988,3.4824313391046253)
# 81
# [ 0.60046135  1.84264222  0.1806343 ]
# Starting trial at position (-93.223153204792,-2.1891085972410407)
# 479
# [ 0.61031309  1.89268542  0.1827072 ]
# Starting trial at position (-77.97844617380363,-3.834669165188852)
# 149
# [ 0.62731666  1.932421    0.1865766 ]
# Starting trial at position (-129.58396844857032,0.7386824118879867)
# 118
# [ 0.64353649  1.96860069  0.19030485]
# Starting trial at position (-124.38745617299651,-4.4283121262134815)
# 108
# [ 0.65547327  2.01136781  0.19603684]
# Starting trial at position (-77.3626278247537,2.8101632097813205)
# 199
# [ 0.67273876  2.05210173  0.19986607]
# Starting trial at position (-52.60126017413674,0.2726829402851685)
# 94
# [ 0.68661783  2.09248646  0.20649188]
# Starting trial at position (-89.22204194147812,-3.9400980660307425)
# 195
# [ 0.69897045  2.13692795  0.20932479]
# Starting trial at position (-127.10891387650145,2.986076049913531)
# 112
# [ 0.7115216   2.17221497  0.21547572]
# Starting trial at position (-90.17670510756844,-3.9185734447928713)
# 286
# [ 0.72341907  2.20164376  0.2206597 ]
# Starting trial at position (-74.32649756160966,-1.3039022135047853)
# 141
# [ 0.73343886  2.25177285  0.2256124 ]
# Starting trial at position (-108.12883739206657,-0.6080759345644013)
# 220
# [ 0.74577229  2.29578736  0.23170077]
# Starting trial at position (-95.8112648114375,-4.059020173642198)
# 234
# [ 0.75626465  2.34453753  0.23424416]
# Starting trial at position (-101.81465074725284,-1.1871540254918123)
# 254
# [ 0.76449637  2.39389607  0.2362949 ]
# Starting trial at position (-55.80759835968267,-3.5366966036197365)
# 98
# [ 0.78175419  2.43103267  0.24035552]
# Starting trial at position (-86.64279530987513,-4.887212351615212)
# 161
# [ 0.79393098  2.47836851  0.24631896]
# Starting trial at position (-107.89366745577435,3.6848618404141895)
# 207
# [ 0.80616005  2.52047196  0.25174891]
# Starting trial at position (-95.71567440284808,3.282592240570482)
# 267
# [ 0.8210454   2.56408601  0.25515137]
# Starting trial at position (-53.38261904656056,-2.520122975213824)
# 105
# [ 0.84026602  2.59584813  0.25963291]
# Starting trial at position (-93.83439926260499,-1.1733094339102368)
# 267
# [ 0.85313861  2.63232808  0.2655848 ]
# Starting trial at position (-88.72387455024742,1.448407184914096)
# 237
# [ 0.86688839  2.67122542  0.27232126]
# Starting trial at position (-113.76309923278467,1.3521399925004598)
# 177
# [ 0.87897761  2.70985789  0.27854865]
# Starting trial at position (-100.58450440183846,2.0630596510551777)
# 271
# [ 0.88537742  2.76072565  0.28171597]
# Starting trial at position (-69.71322518597017,-3.7738779699217573)
# 126
# [ 0.90312922  2.79390886  0.28628152]
# Starting trial at position (-91.76424870797744,2.2426515005322187)
# 231
# [ 0.9202371   2.82398911  0.29074719]
# Starting trial at position (-84.96299145183964,-4.495944880082007)
# 193
# [ 0.93271869  2.85923857  0.2973256 ]
# Starting trial at position (-106.5174756461368,2.3987367860705007)
# 298
# [ 0.93703739  2.91205617  0.2985608 ]
# Starting trial at position (-92.48061206205003,-3.1057457037442058)
# 183
# [ 0.94850653  2.94881093  0.3046529 ]
# Starting trial at position (-65.96034200271193,-1.4527542875980028)
# 118
# [ 0.9590065   3.00042863  0.30990993]
# Starting trial at position (-119.07162526725426,0.34142938649522847)
# 161
# [ 0.97553342  3.03887176  0.31405251]
# Starting trial at position (-91.50532122213005,3.380868769007982)
# 176
# [ 0.97994471  3.09241185  0.31673581]
# Starting trial at position (-87.58820780082698,3.962425273274741)
# 149
# [ 0.99597218  3.13447751  0.32081938]
# Starting trial at position (-129.22074376679743,3.6088618109955064)
# 58
# [ 1.0013245   3.18803412  0.32259518]
# Starting trial at position (-102.8617687092813,4.6362085407689015)
# 153
# [ 1.01381815  3.23588237  0.32636912]
# Starting trial at position (-75.491606468107,-4.992328147397838)
# 127
# [ 1.02802243  3.26129249  0.33360482]
# Starting trial at position (-94.23766682174691,2.1586292219774714)
# 263
# [ 1.0393785   3.28340922  0.33930484]
# Starting trial at position (-54.08237534948698,4.509615971975263)
# 72
# [ 1.05334071  3.3266497   0.3428615 ]
# Starting trial at position (-104.2488279210447,-4.090050746850941)
# 165
# [ 1.06163411  3.37660951  0.34510702]
# Starting trial at position (-120.04514934589834,-1.7422685619373013)
# 194
# [ 1.07490794  3.40513354  0.35197318]
# Starting trial at position (-81.0982729034684,1.0170908650847643)
# 175
# [ 1.08429019  3.4545158   0.35443091]
# Starting trial at position (-101.88342114332023,2.548789256394489)
# 229
# [ 1.09851976  3.48444522  0.36167673]
# Starting trial at position (-127.22163379782998,2.226268219135603)
# 107
# [ 1.10997753  3.51898675  0.3676332 ]
# Starting trial at position (-61.12068938293834,-0.6851626039176697)
# 126
# [ 1.1156139   3.56770963  0.37066901]
# Starting trial at position (-63.98040462235336,-3.216123261688455)
# 127
# [ 1.1292847   3.59448945  0.37789505]
# Starting trial at position (-86.22047921554278,2.3266732175144798)
# 173
# [ 1.13747298  3.64554505  0.38230281]
# Starting trial at position (-102.35559423326539,1.0597747564040727)
# 204
# [ 1.15124202  3.68307647  0.38873819]
# Starting trial at position (-111.88830027559588,3.208414913016517)
# 160
# [ 1.16750494  3.71685673  0.3928558 ]
# Starting trial at position (-102.61892597633766,0.33679166134294913)
# 243
# [ 1.17968272  3.74872799  0.39924639]
# Starting trial at position (-55.69945919621435,-4.298714882164648)
# 64
# [ 1.18996604  3.79816735  0.40251418]
# Starting trial at position (-109.47452552269922,0.8978870958317122)
# 203
# [ 1.2078471   3.83866615  0.40715629]
# Starting trial at position (-78.68923772206121,-0.4350160784509436)
# 176
# [ 1.22612929  3.87111506  0.41183538]
# Starting trial at position (-117.41592845848585,-2.736161367393205)
# 131
# [ 1.23769664  3.91177799  0.41824984]
# Starting trial at position (-121.89749999915628,3.0682082781418547)
# 134
# [ 1.24964889  3.94347071  0.42510632]
# Starting trial at position (-52.713928422174305,-3.597496648425925)
# 98
# [ 1.26560305  3.97573307  0.42944509]
# Starting trial at position (-86.26436489556393,0.7715759717567874)
# 212
# [ 1.27924935  3.99434073  0.43654537]
# Starting trial at position (-67.06425088525413,-4.717388784271105)
# 132
# [ 1.29080141  4.01696044  0.44082964]
# Starting trial at position (-124.50661041017084,1.3115701539469757)
# 150
# [ 1.30443807  4.03611112  0.44790844]
# Starting trial at position (-110.09503289132813,1.8688939547847276)
# 209
# [ 1.3181744   4.07008671  0.45139326]
# Starting trial at position (-83.08038501113252,-2.7522918824072793)
# 139
# [ 1.32932289  4.12135603  0.45728199]
# [ 3198.   400.   232.   372.  1796.  1630.  2166.   138.   131.  2164.
#    702.  1176.   762.    99.   435.   115.   534.   100.   621.   145.
#    268.   428.   113.   142.   467.   188.   200.   175.   122.   215.
#    102.   264.   253.   307.   441.   293.   141.   265.   259.   294.
#    129.    81.   479.   149.   118.   108.   199.    94.   195.   112.
#    286.   141.   220.   234.   254.    98.   161.   207.   267.   105.
#    267.   237.   177.   271.   126.   231.   193.   298.   183.   118.
#    161.   176.   149.    58.   153.   127.   263.    72.   165.   194.
#    175.   229.   107.   126.   127.   173.   204.   160.   243.    64.
#    203.   176.   131.   134.    98.   212.   132.   150.   209.   139.]

# %%
a.visualize_trial(max_steps,tau)
plb.show()
# Out:
# Simulating for:
# [ 4.03167201  1.97299847  0.73987833]
# /Users/vidit/Semester3/Unsupervised Learning NN/unsupNN/Project2/NeuralAgent_v3.py:179: VisibleDeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   self.mountain_car.apply_force(self.force[self.action])
# reward obtained at t =  269.0

# %%
plb.plot(latencies)

# %%
k=10
skip =  (slice(None,None,k),slice(None,None,k))
x = np.linspace(-150,30,n_neurons*10)
x_dot  = np.linspace(-15,15,n_neurons*10)
u,v = np.meshgrid(x,x_dot)
        
vec = vec_field[0]
dummy = np.zeros((vec.shape[0],vec.shape[1]))
Q= plb.quiver(u[skip],v[skip],vec[skip],dummy[skip])

# %%
vec = vec_field[1]
Q= plb.quiver(u[skip],v[skip],vec[skip],dummy[skip])

# %%
vec = vec_field[2]
Q= plb.quiver(u[skip],v[skip],vec[skip],dummy[skip])

# %%
vec = vec_field[3]
Q= plb.quiver(u[skip],v[skip],vec[skip],dummy[skip])

# %%
vec = vec_field[4]
Q= plb.quiver(u[skip],v[skip],vec[skip],dummy[skip])
