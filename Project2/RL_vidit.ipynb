# %%
# Dependencies
import sys
import pylab as plb
import numpy as np
import mountaincar
import DummyAgent as DA
import NeuralAgent_v1 as NA1
# %matplotlib inline

# %%
n_neurons = 20 # Actually a n_neuros x n_neurons grid
tau = 0.008 #Exploration temperature parameter
eta = 0.09 #Learning rate
gamma = 0.95 #Reward factor
lambda_eligibility = 0.8 #elegibility decay
a = NA1.NeuralAgent(n_neurons,tau,eta,gamma,lambda_eligibility)
# Out:
# [-150.         -140.52631579 -131.05263158 -121.57894737 -112.10526316
#  -102.63157895  -93.15789474  -83.68421053  -74.21052632  -64.73684211
#   -55.26315789  -45.78947368  -36.31578947  -26.84210526  -17.36842105
#    -7.89473684    1.57894737   11.05263158   20.52631579   30.        ]
# 9.47368421053
# [-15.         -13.42105263 -11.84210526 -10.26315789  -8.68421053
#   -7.10526316  -5.52631579  -3.94736842  -2.36842105  -0.78947368
#    0.78947368   2.36842105   3.94736842   5.52631579   7.10526316
#    8.68421053  10.26315789  11.84210526  13.42105263  15.        ]
# 1.57894736842

# %%
N_trials = 100
N_runs=1
max_steps = 10000 #Save stop if not working well
latencies = a.run(N_trials,N_runs,max_steps)
print(latencies)
# Out:
# Starting trial at position (-63.91896107706526,-4.726799714394393)
# /Users/vidit/Semester3/Unsupervised Learning NN/unsupNN/Project2/NeuralAgent_v1.py:196: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if self.action_old != None:
# [ 0.12409457  0.38828235  0.66575543]
# 531
# Starting trial at position (-116.26886571600922,0.934166570601521)
# [ 0.21999328  0.67126115  1.58412235]
# 699
# Starting trial at position (-52.01992440358336,1.724962909216691)
# [ 0.25263764  0.7782964   2.77256515]
# 233
# Starting trial at position (-129.2201936789144,2.346874444412008)
# [ 0.33888958  1.31584552  3.44506866]
# 380
# Starting trial at position (-89.5825039264869,-1.0168314544303225)
# [ 0.45226996  1.84174698  3.99750776]
# 5146
# Starting trial at position (-77.41161868019535,-1.6061749507168708)
# [ 0.50009463  2.08938913  5.10359598]
# 1535
# Starting trial at position (-85.24187962842531,4.316381476924439)
# ...

# %%
a.visualize_trial(max_steps)
plb.show()
# Out:
# Simulating for:
# [ 13.18985487  12.16035903  29.51813088]
# reward obtained at t =  690.0

# %%
plb.plot(latencies)
